# %%
import os
from EgoExoEMSDataset import *
# Out:
# /home/cjh9fw/.local/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/sfs/qumulo/qhome/cjh9fw/.local/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
root = "/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Datasets/North_Garden/May_2024/May24_updated_structure/ego_camera/ng1/1/"  # Folder in which all videos lie in a specific structure
annotation_file = "../../Tools/video_annotations.csv"  # A row for each video sample as: (VIDEO_PATH START_FRAME END_FRAME CLASS_ID)

dataset = EgoExoEMSDataset(annotation_file='../../Tools/output_structure.json',
                                video_base_path='',
                                fps=30, frames_per_clip=None, transform=transform)

# Access a sample
print(len(dataset))

# create a data loader
# batch size is 1 for simplicity and to ensure only a full clip related to a key step is given without collating.
# if batch size is greater than 1, collate_fn will be called to collate the data.
data_loader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True, collate_fn=collate_fn)
# Out:
# [{'subject_id': 'ng1', 'trials': [{'trial_id': '1', 'streams': {'vl6180_ToF_depth': {'file_id': 'depth_sensor_2024-05-23-20_05_23', 'file_path': '/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Datasets/North_Garden/May_2024/May24_updated_structure/depth_sensor/ng1/1/depth_sensor_2024-05-23-20_05_23.txt', 'fps': 60, 'protocol': 'Cardiac Arrest - 2-1', 'interventions': [], 'keysteps': []}, 'egocam_rgb_audio': {'file_id': 'GX010305', 'file_path': '/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Datasets/North_Garden/May_2024/May24_updated_structure/ego_camera/ng1/1/GX010305.MP4', 'protocol': 'Cardiac Arrest - 2-1', 'interventions': [], 'keysteps': [{'keystep_id': '1_gpOXHjPd', 'start_t': 0.008, 'end_t': 2.88275, 'label': 'approach_patient', 'class_id': 1}, {'keystep_id': '1_4W1h7RPK', 'start_t': 2.79942, 'end_t': 5.13275, 'label': 'check_responsiveness', 'class_id': 2}, {'keystep_id': '1_BrKnaWXP', 'start_t': 5.133, 'end_t': 7.52858, 'label': 'check_pulse_breathing', 'class_id': 3}, {'keystep_id': '1_9p0HnWaO', 'start_t': 7.52858, 'end_t': 53.40358, 'label': 'begin_chest_compression', 'class_id': 4}, {'keystep_id': '1_3OiNeIks', 'start_t': 53.404, 'end_t': 54.90358, 'label': 'no_action', 'class_id': 5}, {'keystep_id': '1_h0Yo4fiA', 'start_t': 54.96608, 'end_t': 57.90358, 'label': 'take_defib_pads', 'class_id': 6}, {'keystep_id': '1_2s86Yd2m', 'start_t': 58.02858, 'end_t': 60.46608, 'label': 'attach_defib_pads', 'class_id': 7}, {'keystep_id': '1_BFRQXfD5', 'start_t': 60.46608, 'end_t': 61.19525, 'label': 'take_defib_pads', 'class_id': 6}, {'keystep_id': '1_lXGfY9LE', 'start_t': 61.21608, 'end_t': 63.34, 'label': 'attach_defib_pads', 'class_id': 7}, {'keystep_id': '1_NOzgpig0', 'start_t': 63.36192, 'end_t': 79.17442, 'label': 'begin_chest_compression', 'class_id': 4}, {'keystep_id': '1_irbrX69Q', 'start_t': 79.40358, 'end_t': 88.19525, 'label': 'administer_shock_aed', 'class_id': 8}, {'keystep_id': '1_beZ1Njdq', 'start_t': 88.23692, 'end_t': 106.29942, 'label': 'begin_chest_compression', 'class_id': 4}, {'keystep_id': '1_D3qXugyU', 'start_t': 106.299, 'end_t': 107.44525, 'label': 'place_bvm', 'class_id': 9}, {'keystep_id': '1_gbMXdr1R', 'start_t': 107.445, 'end_t': 112.23692, 'label': 'compress_bvm', 'class_id': 10}, {'keystep_id': '1_eXdfBRR6', 'start_t': 112.121, 'end_t': 125.76034, 'label': 'begin_chest_compression', 'class_id': 4}, {'keystep_id': '1_PsSZXfoi', 'start_t': 126.28811, 'end_t': 127.70478, 'label': 'place_bvm', 'class_id': 9}, {'keystep_id': '1_9oLXZzZ9', 'start_t': 127.773, 'end_t': 131.37145, 'label': 'compress_bvm', 'class_id': 10}, {'keystep_id': '1_b5w6teD5', 'start_t': 127.773, 'end_t': 128.773, 'label': 'begin_chest_compression', 'class_id': 4}, {'keystep_id': '1_lCtyTuRy', 'start_t': 131.258, 'end_t': 145.34937, 'label': 'begin_chest_compression', 'class_id': 4}, {'keystep_id': '1_PHHevV23', 'start_t': 145.349, 'end_t': 154.53118, 'label': 'administer_shock_aed', 'class_id': 8}]}, 'exocam_rgbd': {'file_id': '2024-05-23-20-04-48', 'file_path': '/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Datasets/North_Garden/May_2024/May24_updated_structure/RGBD_camera/ng1/1/2024-05-23-20-04-48.mkv', 'protocol': 'Cardiac Arrest - 2-1', 'interventions': [], 'keysteps': []}}}, {'trial_id': '2', 'streams': {'vl6180_ToF_depth': {'file_id': 'depth_sensor_2024-05-23-20_10_58', 'file_path': '/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Datasets/North_Garden/May_2024/May24_updated_structure/depth_sensor/ng1/2/depth_sensor_2024-05-23-20_10_58.txt', 'protocol': 'Cardiac Arrest - 2-1', 'interventions': [], 'keysteps': []}, 'egocam_rgb_audio': {'file_id': 'GX010306', 'file_path': '/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Datasets/North_Garden/May_2024/May24_updated_structure/ego_camera/ng1/2/GX010306.MP4', 'protocol': 'Cardiac Arrest - 2-1', 'interventions': [], 'keysteps': []}, 'exocam_rgbd': {'file_id': '2024-05-23-20-10-54', 'file_path': '/standard/UVA-DSA/NIST EMS Project Data/CognitiveEMS_Dat ...
# 20

# %%
# Iterate over the data loader and print the shape of the batch
for batch in data_loader:
    print(batch['frames'].shape, batch['keystep_label'], batch['keystep_id'], batch['start_frame'], batch['end_frame'])
    # break
# Out:
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3097]) tensor([3127])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1335]) tensor([1365])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2502]) tensor([2532])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4510]) tensor([4540])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3997]) tensor([4027])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3693]) tensor([3723])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2917]) tensor([2947])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4297]) tensor([4327])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3543]) tensor([3573])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4357]) tensor([4361])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([495]) tensor([525])
# torch.Size([1, 30, 3, 224, 224]) ['check_pulse_breathing'] tensor([3]) tensor([183]) tensor([213])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([795]) tensor([825])
# torch.Size([1, 30, 3, 224, 224]) ['attach_defib_pads'] tensor([7]) tensor([1836]) tensor([1866])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([975]) tensor([1005])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([255]) tensor([285])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2622]) tensor([2646])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1305]) tensor([1335])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4420]) tensor([4450])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3863]) tensor([3893])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2260]) tensor([2290])
# torch.Size([1, 30, 3, 224, 224]) ['place_bvm'] tensor([9]) tensor([3188]) tensor([3218])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3343]) tensor([3368])
# torch.Size([1, 30, 3, 224, 224]) ['check_pulse_breathing'] tensor([3]) tensor([153]) tensor([183])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2887]) tensor([2917])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4450]) tensor([4480])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2857]) tensor([2887])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1900]) tensor([1930])
# torch.Size([1, 30, 3, 224, 224]) ['attach_defib_pads'] tensor([7]) tensor([1770]) tensor([1800])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4027]) tensor([4057])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2647]) tensor([2677])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3923]) tensor([3942])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([855]) tensor([885])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2110]) tensor([2140])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2200]) tensor([2230])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3937]) tensor([3967])
# torch.Size([1, 30, 3, 224, 224]) ['attach_defib_pads'] tensor([7]) tensor([1896]) tensor([1901])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4390]) tensor([4420])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3573]) tensor([3603])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3723]) tensor([3753])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3423]) tensor([3453])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2020]) tensor([2050])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([915]) tensor([945])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4177]) tensor([4207])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4630]) tensor([4636])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([615]) tensor([645])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([765]) tensor([795])
# torch.Size([1, 30, 3, 224, 224]) ['take_defib_pads'] tensor([6]) tensor([1648]) tensor([1678])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([705]) tensor([735])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2532]) tensor([2562])
# torch.Size([1, 30, 3, 224, 224]) ['no_action'] tensor([5]) tensor([1632]) tensor([1648])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3007]) tensor([3037])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2350]) tensor([2376])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([285]) tensor([315])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1095]) tensor([1125])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([825]) tensor([855])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4147]) tensor([4177])
# torch.Size([1, 30, 3, 224, 224]) ['place_bvm'] tensor([9]) tensor([3788]) tensor([3818])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([585]) tensor([615])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2977]) tensor([3007])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([405]) tensor([435])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2442]) tensor([2472])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1930]) tensor([1960])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1575]) tensor([1603])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3513]) tensor([3543])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1065]) tensor([1095])
# torch.Size([1, 30, 3, 224, 224]) ['place_bvm'] tensor([9]) tensor([3818]) tensor([3832])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2767]) tensor([2797])
# torch.Size([1, 30, 3, 224, 224]) ['no_action'] tensor([5]) tensor([1602]) tensor([1632])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([555]) tensor([585])
# torch.Size([1, 30, 3, 224, 224]) ['take_defib_pads'] tensor([6]) tensor([1813]) tensor([1836])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4570]) tensor([4600])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2707]) tensor([2737])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3223]) tensor([3253])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4480]) tensor([4510])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4237]) tensor([4267])
# torch.Size([1, 30, 3, 224, 224]) ['place_bvm'] tensor([9]) tensor([3218]) tensor([3224])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1455]) tensor([1485])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3453]) tensor([3483])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2050]) tensor([2080])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2797]) tensor([2827])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([465]) tensor([495])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4087]) tensor([4117])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([525]) tensor([555])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2320]) tensor([2350])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2412]) tensor([2442])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1960]) tensor([1990])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3283]) tensor([3313])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([225]) tensor([255])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1990]) tensor([2020])
# torch.Size([1, 30, 3, 224, 224]) ['attach_defib_pads'] tensor([7]) tensor([1866]) tensor([1896])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4540]) tensor([4570])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4117]) tensor([4147])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3393]) tensor([3423])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2382]) tensor([2412])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3967]) tensor([3997])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4057]) tensor([4087])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2562]) tensor([2592])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([315]) tensor([345])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3363]) tensor([3393])
# torch.Size([1, 30, 3, 224, 224]) ['attach_defib_pads'] tensor([7]) tensor([1740]) tensor([1770])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1155]) tensor([1185])
# torch.Size([1, 30, 3, 224, 224]) ['check_pulse_breathing'] tensor([3]) tensor([213]) tensor([226])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1215]) tensor([1245])
# torch.Size([1, 30, 3, 224, 224]) ['check_responsiveness'] tensor([2]) tensor([143]) tensor([154])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2080]) tensor([2110])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4207]) tensor([4237])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3633]) tensor([3663])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([345]) tensor([375])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1485]) tensor([1515])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2737]) tensor([2767])
# torch.Size([1, 30, 3, 224, 224]) ['check_responsiveness'] tensor([2]) tensor([83]) tensor([113])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([945]) tensor([975])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2170]) tensor([2200])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3893]) tensor([3923])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3753]) tensor([3773])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3253]) tensor([3283])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2472]) tensor([2502])
# [ WARN:0@229.147] global cap_ffmpeg_impl.hpp:1541 grabFrame packet read max attempts exceeded, if your video have multiple streams (video, audio) try to increase attempt limit by setting environment variable OPENCV_FFMPEG_READ_ATTEMPTS (current value is 4096)
# torch.Size([1, 30, 3, 224, 224]) ['approach_patient'] tensor([1]) tensor([30]) tensor([60])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3663]) tensor([3693])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1365]) tensor([1395])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3603]) tensor([3633])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1545]) tensor([1575])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4267]) tensor([4297])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3313]) tensor([3343])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2947]) tensor([2977])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([375]) tensor([405])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3127]) tensor([3157])
# torch.Size([1, 30, 3, 224, 224]) ['take_defib_pads'] tensor([6]) tensor([1708]) tensor([1738])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3037]) tensor([3067])
# torch.Size([1, 30, 3, 224, 224]) ['attach_defib_pads'] tensor([7]) tensor([1800]) tensor([1814])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2677]) tensor([2707])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([735]) tensor([765])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2827]) tensor([2857])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3067]) tensor([3097])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3187]) tensor([3189])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4600]) tensor([4630])
# torch.Size([1, 30, 3, 224, 224]) ['approach_patient'] tensor([1]) tensor([60]) tensor([87])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1395]) tensor([1425])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1425]) tensor([1455])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([4327]) tensor([4357])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1125]) tensor([1155])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1005]) tensor([1035])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([2592]) tensor([2622])
# torch.Size([1, 30, 3, 224, 224]) ['check_responsiveness'] tensor([2]) tensor([113]) tensor([143])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3483]) tensor([3513])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1035]) tensor([1065])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2290]) tensor([2320])
# [ WARN:0@288.817] global cap_ffmpeg_impl.hpp:1541 grabFrame packet read max attempts exceeded, if your video have multiple streams (video, audio) try to increase attempt limit by setting environment variable OPENCV_FFMPEG_READ_ATTEMPTS (current value is 4096)
# torch.Size([1, 30, 3, 224, 224]) ['approach_patient'] tensor([1]) tensor([0]) tensor([30])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1275]) tensor([1305])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([645]) tensor([675])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2230]) tensor([2260])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3157]) tensor([3187])
# torch.Size([1, 30, 3, 224, 224]) ['compress_bvm'] tensor([10]) tensor([3833]) tensor([3863])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1515]) tensor([1545])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([2140]) tensor([2170])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1185]) tensor([1215])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3833]) tensor([3863])
# torch.Size([1, 30, 3, 224, 224]) ['take_defib_pads'] tensor([6]) tensor([1678]) tensor([1708])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([1245]) tensor([1275])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([435]) tensor([465])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([675]) tensor([705])
# torch.Size([1, 30, 3, 224, 224]) ['administer_shock_aed'] tensor([8]) tensor([4360]) tensor([4390])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([885]) tensor([915])
# torch.Size([1, 30, 3, 224, 224]) ['begin_chest_compression'] tensor([4]) tensor([3863]) tensor([3864])
